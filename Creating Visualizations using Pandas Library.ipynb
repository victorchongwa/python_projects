# %%
import pandas as pd
import numpy as np
import matplotlib as ptl

# %%
df = pd.read_csv(r"C:\Users\V!ctor_Frankenste!n\Downloads\Documents\pandas files\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind = 'line', title = 'ice cream ratings', xlabel ='daily ratings', ylabel = 'scores')
# Out:
# <Axes: title={'center': 'ice cream ratings'}, xlabel='daily ratings', ylabel='scores'>

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Flavor Rating', s = 200, color = 'pink')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
df.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.pie(y = 'Flavor Rating', figsize = (10,6))
# Out:
# <Axes: ylabel='Flavor Rating'>
